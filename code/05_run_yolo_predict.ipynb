# %%
import os

os.chdir('../code/yolov5/')

os.getcwd()
# Out:
# 'D:\\Jupyter_Data\\tile_tianchi\\yolov5'

# %% [markdown]
# ``` python
# python detect.py --source ../temp_test/imgs_sliced_160 --weights ./runs/train/exp8/weights/best.pt --save-txt --img-size 160
# ```

# %%
# %run detect.py --source ../round1_testA_sliced_all_1280 --weights ./runs/train/exp59/weights/last.pt --save-txt --save-conf --img-size 1280
# Out:
# Using torch 1.6.0+cu101 CUDA:0 (GeForce RTX 2060, 6144MB)
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=320, iou_thres=0.45, name='exp', project='runs/detect', save_conf=True, save_txt=True, source='../round1_testA_sliced_all_320', update=False, view_img=False, weights=['./runs/train/exp41/weights/last.pt'])
# Fusing layers...
# Model Summary: 232 layers, 7262700 parameters, 0 gradients
# ...
